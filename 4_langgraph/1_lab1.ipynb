# %% [markdown]
# ## Welcome back to Python Notebooks!
#
# Didja miss me??
#
# ### And welcome to Week 4, Day 2 - introducing LangGraph!

# %%
from typing import Annotated
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.graph import StateGraph
from langgraph.graph.message import add_messages
from langchain_openai import ChatOpenAI
from pydantic import BaseModel
import random

# %%
# Some useful constants

nouns = ["Cabbages", "Unicorns", "Toasters", "Penguins", "Bananas", "Zombies", "Rainbows", "Eels", "Pickles", "Muffins"]
adjectives = ["outrageous", "smelly", "pedantic", "existential", "moody", "sparkly", "untrustworthy", "sarcastic", "squishy", "haunted"]

# %%
# Our favorite first step! Crew was doing this for us, by the way.
load_dotenv(override=True)
# Out:
# True

# %%
def shout(text: Annotated[str, "something to be shouted"]) -> str:
    print(text.upper())
    return text.upper()

shout("hello")
# Out:
# HELLO
# 'HELLO'

# %% [markdown]
# ### A word about "Annotated"
#
# You probably know this; type hinting is a feature in Python that lets you specify the type of something:
#
# `my_favorite_things: List`
#
# But you may not know this:
#
# You can also use something called "Annotated" to add extra information that somebody else might find useful:
#
# `my_favorite_things: Annotated[List, "these are a few of mine"]`
#
# LangGraph needs us to use this feature when we define our State object.
#
# It wants us to tell it what function it should call to update the State with a new value.
#
# This function is called a **reducer**.
#
# LangGraph provides a default reducer called `add_messages` which takes care of the most common case.
#
# And that hopefully explains why the State looks like this.

# %% [markdown]
# ### Step 1: Define the State object
#
# You can use any python object; but it's most common to use a TypedDict or a Pydantic BaseModel.

# %%
class State(BaseModel):
        
    messages: Annotated[list, add_messages]

# %% [markdown]
# ### Step 2: Start the Graph Builder with this State class

# %%
graph_builder = StateGraph(State)

# %% [markdown]
# ### Step 3: Create a Node
#
# A node can be any python function.
#
# The reducer that we set before gets automatically called to combine this response with previous responses

# %%
def our_first_node(old_state: State) -> State:

    reply = f"{random.choice(nouns)} are {random.choice(adjectives)}"
    messages = [{"role": "assistant", "content": reply}]

    new_state = State(messages=messages)

    return new_state

graph_builder.add_node("first_node", our_first_node)

# %% [markdown]
# ### Step 4: Create Edges

# %%
graph_builder.add_edge(START, "first_node")
graph_builder.add_edge("first_node", END)

# %% [markdown]
# ### Step 5: Compile the Graph

# %%
graph = graph_builder.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### That's it! Showtime!

# %%
def chat(user_input: str, history):
    message = {"role": "user", "content": user_input}
    messages = [message]
    state = State(messages=messages)
    result = graph.invoke(state)
    print(result)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# {'messages': [HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}, id='af09ed28-9845-4073-95a7-27f21e6d9d33'), AIMessage(content='Zombies are squishy', additional_kwargs={}, response_metadata={}, id='08cd81de-4364-43c8-b388-7eb9a6d027be')]}
# {'messages': [HumanMessage(content='next', additional_kwargs={}, response_metadata={}, id='3122b03a-ecb9-480e-b9a6-37d496f5d692'), AIMessage(content='Penguins are squishy', additional_kwargs={}, response_metadata={}, id='d98c5f63-c742-4d97-b76f-3ea41335c889')]}
# {'messages': [HumanMessage(content='', additional_kwargs={}, response_metadata={}, id='c7bb4adc-f14d-4cc2-9c44-4895dc9b292d'), AIMessage(content='Eels are haunted', additional_kwargs={}, response_metadata={}, id='94199ce0-496e-43ce-b054-b6841e29c60c')]}
# {'messages': [HumanMessage(content='', additional_kwargs={}, response_metadata={}, id='7db843a7-9fd9-475e-8e16-fd43064eee68'), AIMessage(content='Toasters are smelly', additional_kwargs={}, response_metadata={}, id='6538ee74-22cf-4ddd-8614-9c1a054bc522')]}
# {'messages': [HumanMessage(content='', additional_kwargs={}, response_metadata={}, id='f11e6e92-6c57-47c2-8fd4-462746d48f73'), AIMessage(content='Rainbows are outrageous', additional_kwargs={}, response_metadata={}, id='c8fb51fc-4676-471c-8149-0f6f21fb9c9d')]}
# {'messages': [HumanMessage(content='', additional_kwargs={}, response_metadata={}, id='1b451f1e-0e94-4a4b-878b-892db6b4467b'), AIMessage(content='Toasters are smelly', additional_kwargs={}, response_metadata={}, id='3e638921-d45a-42bb-a00f-4e4c626cb1db')]}
# {'messages': [HumanMessage(content='', additional_kwargs={}, response_metadata={}, id='8f844349-f3f7-44ef-9b2b-580c6d46f475'), AIMessage(content='Bananas are squishy', additional_kwargs={}, response_metadata={}, id='d45dd3e0-ce1d-48b9-be59-0814b8e45b85')]}
# {'messages': [HumanMessage(content='', additional_kwargs={}, response_metadata={}, id='3393d69a-9bfa-46e4-8432-772ccccca6bc'), AIMessage(content='Rainbows are squishy', additional_kwargs={}, response_metadata={}, id='9b372720-0d00-4af8-8358-3a913cf9c0a8')]}
# {'messages': [HumanMessage(content='', additional_kwargs={}, response_metadata={}, id='72d7e962-0cbc-4139-9edc-0460d490ef66'), AIMessage(content='Pickles are moody', additional_kwargs={}, response_metadata={}, id='98f1d1cd-d9f9-4e17-a930-6bab1a01b9af')]}
# {'messages': [HumanMessage(content='', additional_kwargs={}, response_metadata={}, id='1086a233-eb77-480e-a30b-fdffe37a1c4d'), AIMessage(content='Penguins are smelly', additional_kwargs={}, response_metadata={}, id='37e364f1-9b2b-4038-be90-a7e59dadf355')]}
# {'messages': [HumanMessage(content='', additional_kwargs={}, response_metadata={}, id='fb90d001-4bfd-4f11-b861-6978dccfad8e'), AIMessage(content='Unicorns are moody', additional_kwargs={}, response_metadata={}, id='01ebd0cf-9e2c-401f-8858-97ab795eff5c')]}
# {'messages': [HumanMessage(content='', additional_kwargs={}, response_metadata={}, id='f250f165-d5e4-4c5e-85cc-777549d878ef'), AIMessage(content='Rainbows are pedantic', additional_kwargs={}, response_metadata={}, id='635ac80b-eaf9-42a3-b9f5-46a5463eb419')]}
# {'messages': [HumanMessage(content='', additional_kwargs={}, response_metadata={}, id='86bbe22f-40b7-4eb8-8fe6-94bab1e944ba'), AIMessage(content='Muffins are sparkly', additional_kwargs={}, response_metadata={}, id='d2476d8a-03e5-4712-8e37-4be7ba5c7b78')]}

# %% [markdown]
# ### But why did I show you that?
#
# To make the point that LangGraph is all about python functions - it doesn't need to involve LLMs!!
#
# Now we'll do the 5 steps again, but in 1 shot:

# %%
# Step 1: Define the State object
class State(BaseModel):
    messages: Annotated[list, add_messages]

# %%
# Step 2: Start the Graph Builder with this State class
graph_builder = StateGraph(State)

# %%
# Step 3: Create a Node

llm = ChatOpenAI(model="gpt-4o-mini")

def chatbot_node(old_state: State) -> State:
    response = llm.invoke(old_state.messages)
    new_state = State(messages=[response])
    return new_state

graph_builder.add_node("chatbot", chatbot_node)

# %%
# Step 4: Create Edges
graph_builder.add_edge(START, "chatbot")
graph_builder.add_edge("chatbot", END)

# %%
# Step 5: Compile the Graph
graph = graph_builder.compile()
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### That's it! And, let's do this:

# %%
def chat(user_input: str, history):
    initial_state = State(messages=[{"role": "user", "content": user_input}])
    result = graph.invoke(initial_state)
    print(result)
    return result['messages'][-1].content


gr.ChatInterface(chat, type="messages").launch()
